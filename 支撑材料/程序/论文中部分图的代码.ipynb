# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette="muted", color_codes=True)    # seaborn样式
import numpy as np
np.set_printoptions(suppress=True)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题

# %%
df=pd.read_excel("../数据/1.xlsx",sheet_name=0)
df
# Out:
#     文物编号  纹饰  类型  颜色  表面风化  文物采样点  二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  \
# 0      1   1   1   1     1      1       69.33       0.00      9.99      6.32
# 1      2   2   2   2     2      2       36.28       0.00      1.05      2.34
# 2      3   2   1   1     1      3       87.05       0.00      5.19      2.01
# 3      3   2   1   1     1      4       61.71       0.00     12.37      5.87
# 4      4   2   1   1     1      5       65.88       0.00      9.67      7.12
# ..   ...  ..  ..  ..   ...    ...         ...        ...       ...       ...
# 64    54   1   2   2     2     65       17.11       0.00      0.00      0.00
# 65    55   1   2   9     1     66       49.01       2.71      0.00      1.13
# 66    56   1   2   1     2     67       29.15       0.00      0.00      1.21
# 67    57   1   2   1     2     68       25.42       0.00      0.00      1.31
# 68    58   1   2   6     2     69       30.39       0.00      0.34      3.49
#
# ...

# %%
y=df["表面风化"]
x=df.iloc[:,1:20]
x.drop(['表面风化', '文物采样点'],axis=1)
cor=df.iloc[:,1:5]
car_cor=cor.corr()

sns.heatmap(car_cor,cmap="coolwarm",annot=True,fmt=".2f",linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=x,y="二氧化硅(SiO2)")
# Out:
# <AxesSubplot:ylabel='二氧化硅(SiO2)'>

# %%
y1=x.iloc[:,6:20]

# %%
sns.boxplot(data=x,y="氧化钾(K2O)")
# sns.boxplot(data=x,y="氧化钙(CaO)")
# sns.boxplot(data=x,y="氧化镁(MgO)")
# sns.boxplot(data=x,y="氧化铝(Al2O3)")
# sns.boxplot(data=x,y="氧化铁(Fe2O3)")
# sns.boxplot(data=x,y="氧化铜(CuO)")
# sns.boxplot(data=x,y="氧化铅(PbO)")
# Out:
# <AxesSubplot:ylabel='氧化钾(K2O)'>

# %%
sns.boxplot(data=x,y="氧化钙(CaO)")
sns.boxplot(data=x,y="氧化镁(MgO)")
# Out:
# <AxesSubplot:ylabel='氧化铁(Fe2O3)'>

# %%
sns.boxplot(data=x,y="氧化铝(Al2O3)")
sns.boxplot(data=x,y="氧化铁(Fe2O3)")
# Out:
# <AxesSubplot:ylabel='氧化铁(Fe2O3)'>

# %%
sns.boxplot(data=x,y="氧化钡(BaO)")
# Out:
# <AxesSubplot:ylabel='氧化钡(BaO)'>

# %%
sns.boxplot(data=x,y="五氧化二磷(P2O5)")
# Out:
# <AxesSubplot:ylabel='五氧化二磷(P2O5)'>

# %%
# sns.boxplot(data=x,y="氧化铅(PbO)")
sns.boxplot(data=x,y="氧化钡(BaO)")
# Out:
# <AxesSubplot:ylabel='氧化钡(BaO)'>

# %%
sns.boxplot(data=x,y="五氧化二磷(P2O5)")
sns.boxplot(data=x,y="氧化铅(PbO)")
# Out:
# <AxesSubplot:ylabel='氧化铅(PbO)'>

# %%
sns.boxplot(data=x,y="氧化钡(BaO)")
# Out:
# <AxesSubplot:ylabel='氧化钡(BaO)'>

# %%
sns.boxplot(data=x,y="氧化钙(CaO)")
# Out:
# <AxesSubplot:ylabel='氧化钙(CaO)'>

# %%
sns.boxplot(data=x,y="五氧化二磷(P2O5)")
# Out:
# <AxesSubplot:ylabel='五氧化二磷(P2O5)'>

# %%
y2=df["表面风化"]
x2=y1
x7=df.iloc[:,6:20]

# %%
import xgboost as xgb
from sklearn.decomposition import PCA

# %%
m7=xgb.XGBRegressor()
m7.fit(x7,y2)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
m7.feature_importances_
# Out:
# array([0.5197314 , 0.04029763, 0.11673065, 0.02186012, 0.00014509,
#        0.02221402, 0.00762273, 0.03459095, 0.19282068, 0.00132088,
#        0.00433273, 0.03787253, 0.00000837, 0.00045211], dtype=float32)

# %%
l1=m7.feature_importances_

# %%
l1=l1[1:]
l2=l1/l1.sum()

# %%
l2.sum()
# Out:
# 1.0000001

# %%
yylabel=(['氧化钠(Na2O)', '氧化钾(K2O)', '氧化钙(CaO)', '氧化镁(MgO)',
       '氧化铝(Al2O3)', '氧化铁(Fe2O3)', '氧化铜(CuO)',
       '氧化铅(PbO)', '氧化钡(BaO)', '五氧化二磷(P2O5)',
       '氧化锶(SrO)', '氧化锡(SnO2)', '二氧化硫(SO2)'])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib as mpl
plt.figure(figsize=(25, 15))
mpl.rcParams['font.sans-serif'] = ['Times New Roman']  
mpl.rcParams['font.weight'] = 'bold'  
mpl.rcParams['font.size'] = 26  
plt.bar(yylabel,l2)
plt.ylabel('W', fontsize=30,fontweight='bold')
ax=plt.gca()
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
# plt.savefig('./bar_example.png', bbox_inches='tight', dpi=1200)
plt.show()
# Out:
# f:\pyhton\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 27687 (\N{CJK UNIFIED IDEOGRAPH-6C27}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\pyhton\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\pyhton\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38048 (\N{CJK UNIFIED IDEOGRAPH-94A0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\pyhton\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38078 (\N{CJK UNIFIED IDEOGRAPH-94BE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# f:\pyhton\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38041 (\N{CJK UNIFIED IDEOGRAPH-9499}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
cor=x7.corr()
# sns.heatmap(cor,cmap="coolwarm")
sns.set(font='SimHei',font_scale=0.6)  # 解决Seaborn中文显示问题并调整字体大小

sns.heatmap(cor,cmap="coolwarm",annot=True,fmt=".2f",linewidth=2)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.pairplot(data=x7,kind="reg")
