# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette="muted", color_codes=True)    # seaborn样式


plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
sns.set(font='SimHei',font_scale=1.5)  # 解决Seaborn中文显示问题并调整字体大小

# %%
df=pd.read_excel("../数据/2.xlsx",sheet_name=0)
X=df.iloc[:,:7]
ccc=df.iloc[:,6:]
y=df.iloc[:,7:]
y.head()
# Out:
#    氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  氧化铝(Al2O3)  氧化铁(Fe2O3)  氧化铜(CuO)  \
# 0        0.0      9.99      6.32      0.87        3.93        1.74      3.87
# 1        0.0      5.19      2.01      0.00        4.06        0.00      0.78
# 2        0.0     12.37      5.87      1.11        5.50        2.16      5.09
# 3        0.0      9.67      7.12      1.56        6.44        2.06      2.18
# 4        0.0     10.95      7.35      1.77        7.50        2.62      3.27
#
#    氧化铅(PbO)  氧化钡(BaO)  五氧化二磷(P2O5)  氧化锶(SrO)  氧化锡(SnO2)  二氧化硫(SO2)
# 0      0.00      0.00         1.17      0.00        0.0       0.39
# 1      0.25      0.00         0.66      0.00        0.0       0.00
# 2      1.41      2.86         0.70      0.10        0.0       0.00
# 3      0.00      0.00         0.79      0.00        0.0       0.36
# 4      0.00      0.00         0.94      0.06        0.0       0.47

# %%
vvv=pd.read_excel("../数据/风化 .xlsx")
vvv.head()
# Out:
#    文物编号  纹饰  类型  颜色  表面风化  文物采样点  二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  \
# 0    33   1   2   4     2     38       75.51       0.00      0.15      0.64
# 1    34   1   2   4     2     39       35.78       0.00      0.25      0.78
# 2    35   1   2   7     2     40       65.91       0.00      0.00      0.38
# 3    36   1   2   4     2     41       39.57       2.22      0.14      0.37
# 4    37   1   2   4     2     42       60.12       0.00      0.23      0.89
#
#    ...  氧化铜(CuO)  氧化铅(PbO)  氧化钡(BaO)  五氧化二磷(P2O5)  氧化锶(SrO)  氧化锡(SnO2)  \
# 0  ...      0.47     16.16      3.55         0.13      0.00        0.0
# 1  ...      1.51     46.55     10.00         0.34      0.22        0.0
# 2  ...      0.16     22.05      5.68         0.42      0.00        0.0
# 3  ...      0.68     41.61     10.83         0.07      0.22        0.0
# 4  ...      3.01     17.24     10.34         1.46      0.31        0.0
#
#    二氧化硫(SO2)    助熔剂   稳定剂   着色剂
# 0       0.00  20.50  2.99  0.60
# ...

# %%
vv=vvv.iloc[:,6:20]

# %%
b=ccc.describe()
vv=vv.describe()

# %%
#第二问统计规律表


#!!!!!!!!!!!!!!!!!!

print("无风化统计：{}\n\n 风化统计：{}".format(b,vv))
# Out:
# 无风化统计：       二氧化硅(SiO2)  氧化钠(Na2O)   氧化钾(K2O)   氧化钙(CaO)   氧化镁(MgO)  氧化铝(Al2O3)  \
# count   37.000000  37.000000  37.000000  37.000000  37.000000   37.000000
# mean    59.339459   1.415405   3.517568   2.550270   0.798649    5.002162
# std     12.167919   2.065236   4.851092   2.799763   0.605008    3.202264
# min     31.940000   0.000000   0.000000   0.000000   0.000000    0.000000
# 25%     51.540000   0.000000   0.110000   0.470000   0.000000    3.050000
# 50%     61.280000   0.000000   0.290000   1.130000   0.870000    4.350000
# 75%     65.910000   2.710000   7.440000   4.490000   1.160000    6.180000
# max     87.050000   7.920000  14.520000   8.700000   1.980000   14.340000
#
#        氧化铁(Fe2O3)   氧化铜(CuO)   氧化铅(PbO)   氧化钡(BaO)  五氧化二磷(P2O5)   氧化锶(SrO)  \
# count   37.000000  37.000000  37.000000  37.000000    37.000000  37.000000
# mean     1.140541   1.749730  13.872162   5.789730     1.118919   0.180270
# ...

# %%
b=pd.DataFrame(b)
vv=pd.DataFrame(vv)

b=b.iloc[6,:]
vv=vv.iloc[6,:]
bv=pd.DataFrame([b,vv])

# %%
x=bv.columns
y1=bv.iloc[0,:]
y2=bv.iloc[1,:]
import matplotlib.pyplot as plt
import numpy as np
# pre-datas
# x = np.arange(1, 11, 1)  # x坐标
plt.plot(x, y1, lw=1, c='red', marker='s', ms=4, label='无风化')  # 绘制y1
plt.plot(x, y2, lw=1, c='g', marker='o', label='风化')  # 绘制y2
# plt-style 
plt.title("75%有无风化成分对比")
plt.xticks(x,rotation=90)  # x轴的刻度
# plt.xlim(0.5, 10.5)  # x轴坐标范围
plt.ylim(0,70) # y轴坐标范围
# plt.xlabel('')  # x轴标注
plt.ylabel('成分含量')  # y轴标注
plt.legend()  # 图例
plt.savefig('e:/test.png')  # 保存图片
plt.show()

# %%
#第三问
'''
采用决策树回归模型预测风化前的化学成分含量

'''
from sklearn.tree import DecisionTreeRegressor


m4=DecisionTreeRegressor()
m4.fit(X,y)
# Out:
# DecisionTreeRegressor()

# %%
date=pd.read_excel("../数据/1-3测试.xlsx")

# %%
import numpy as np
np.set_printoptions(suppress=True)

# %%
# print("RandomForestRegressor决定系数R^2:{},预测结果:{}".format(m3.score(X,y),m3.predict(date)))
print("DecisionTreeRegressor决定系数R^2:{},预测结果:{}".format(m4.score(X,y),m4.predict(date)))
# Out:
# DecisionTreeRegressor决定系数R^2:1.0,预测结果:[[ 0.    0.    0.47  0.    1.59  0.    8.46 29.14 26.23  0.14  0.91  0.
#    0.  ]
#  [ 3.06  0.2   2.14  0.   12.69  0.77  0.43 13.61  5.22  0.    0.26  0.
#    0.  ]
#  [ 0.    0.    0.47  0.    1.59  0.    8.46 29.14 26.23  0.14  0.91  0.
#    0.  ]
#  [ 3.06  0.2   2.14  0.   12.69  0.77  0.43 13.61  5.22  0.    0.26  0.
#    0.  ]
#  [ 0.    0.    0.47  0.    1.59  0.    8.46 29.14 26.23  0.14  0.91  0.
#    0.  ]
#  [ 3.06  0.2   2.14  0.   12.69  0.77  0.43 13.61  5.22  0.    0.26  0.
#    0.  ]
#  [ 3.06  0.2   2.14  0.   12.69  0.77  0.43 13.61  5.22  0.    0.26  0.
#    0.  ]
#  [ 3.06  0.2   2.14  0.   12.69  0.77  0.43 13.61  5.22  0.    0.26  0.
#    0.  ]
#  [ 3.06  0.2   2.14  0.   12.69  0.77  0.43 13.61  5.22  0.    0.26  0.
#    0.  ]
#  [ 0.    1.41  4.49  0.98  4.35  2.12  0.   39.22 10.29  0.    0.35  0.4
#    0.  ]
#  [ 0.    1.41  4.49  0.98  4.35  2.12  0.   39.22 10.29  0.    0.35  0.4
#    0.  ]
# ...
